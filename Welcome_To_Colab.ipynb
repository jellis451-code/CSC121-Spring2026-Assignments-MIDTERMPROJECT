# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-MIDTERMPROJECT/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# validate_classification(code)
#   ensure code is B, S, or L
#   return uppercase valid code

# get_classification_name(code)
#   return full name of classification

# calculate_miles(start, end)
#   return total miles driven

# calculate_charged_miles(total_miles)
#   return miles over 100

# calculate_bill(code, days, charged_miles)
#   NO print statements
#   calculate daily cost + mileage cost
#   return total bill

# PROGRAM LOGIC
# prompt user for classification, odometer readings, days
# call functions
# print formatted rental summary
